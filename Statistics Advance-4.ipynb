# %% [markdown]
# <h1 style="color: red;"><center>Statistics Advance-4</center></h1>

# %% [markdown]
# <h3 style="color: blue;">Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.</h3>
# <p><b>Answer</b></p>
#    <table border="1">
#         <tr>
#             <th>Aspect</th>
#             <th>t-test</th>
#             <th>z-test</th>
#         </tr>
#         <tr>
#             <td>Population Standard Deviation</td>
#             <td>Unknown</td>
#             <td>Known</td>
#         </tr>
#         <tr>
#             <td>Sample Size</td>
#             <td>Small (typically less than 30)</td>
#             <td>Large (typically 30 or more)</td>
#         </tr>
#         <tr>
#             <td>Distribution</td>
#             <td>t-distribution (more spread out with heavier tails)</td>
#             <td>Normal distribution (assuming Central Limit Theorem applies)</td>
#         </tr>
#         <tr>
#             <td>Example Scenario</td>
#             <td>
#                 A researcher wants to compare the average test scores of a sample of 25 students to a known average score. The population standard deviation is not known.
#             </td>
#             <td>
#                 A quality control analyst wants to test if the average weight of a product in a large sample of 100 items matches the target weight. The population standard deviation is known.
#             </td>
#         </tr>
#     </table>

# %% [markdown]
# <h3 style="color: blue;">Q2: Differentiate between one-tailed and two-tailed tests.</h3>
# <p><b>Answer</b></p>
# <table border="1">
#   <tr>
#     <th>Aspect</th>
#     <th>One-Tailed Test</th>
#     <th>Two-Tailed Test</th>
#   </tr>
#   <tr>
#     <td>Definition</td>
#     <td>Tests the effect in one specific direction (either greater than or less than).</td>
#     <td>Tests the effect in both directions (both greater than and less than).</td>
#   </tr>
#   <tr>
#     <td>Hypotheses</td>
#     <td>
#       <strong>Null Hypothesis (H<sub>0</sub>):</strong> No effect or opposite direction.<br>
#       <strong>Alternative Hypothesis (H<sub>a</sub>):</strong> Effect in one specific direction.
#     </td>
#     <td>
#       <strong>Null Hypothesis (H<sub>0</sub>):</strong> No effect.<br>
#       <strong>Alternative Hypothesis (H<sub>a</sub>):</strong> Effect in either direction.
#     </td>
#   </tr>
#   <tr>
#     <td>Critical Region</td>
#     <td>Located in one tail of the distribution.</td>
#     <td>Located in both tails of the distribution.</td>
#   </tr>
#   <tr>
#     <td>Significance Level (α)</td>
#     <td>Entire α is in one tail.</td>
#     <td>α is split between the two tails (α/2 in each tail).</td>
#   </tr>
#   <tr>
#     <td>When to Use</td>
#     <td>When the research hypothesis predicts a direction of the effect.</td>
#     <td>When the research hypothesis does not predict a direction, or when deviations in both directions are important.</td>
#   </tr>
# </table>

# %% [markdown]
# <h3 style="color: blue;">Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.</h3>
# <p><b>Answer</b></p>
# <table>
#     <tr>
#         <th>Error Type</th>
#         <th>Description</th>
#         <th>Example Scenario</th>
#     </tr>
#     <tr>
#         <td>Type 1 Error</td>
#         <td>
#             A Type 1 error occurs when the null hypothesis is true, but it is incorrectly rejected.
#             This is also known as a "false positive" or "alpha error."
#         </td>
#         <td>
#             Suppose a medical test is conducted to check for a disease. The null hypothesis (H0) is that the patient does not have the disease.
#             If the test incorrectly indicates that the patient has the disease when they do not, this is a Type 1 error.
#         </td>
#     </tr>
#     <tr>
#         <td>Type 2 Error</td>
#         <td>
#             A Type 2 error occurs when the null hypothesis is false, but it is incorrectly accepted.
#             This is also known as a "false negative" or "beta error."
#         </td>
#         <td>
#             Using the same medical test scenario, the null hypothesis (H0) is that the patient does not have the disease.
#             If the test incorrectly indicates that the patient does not have the disease when they actually do, this is a Type 2 error.
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h3 style="color: blue;">Q4: Explain Bayes's theorem with an example.</h3>
# <p><b>Answer:</b></p>
# <h5>Bayes's theorem:</h5>
# <p>The bayes's theorem state about the probability of any event if an another event is occure. It take the two probability P(A) and P(B) and give the resultent probabiltiy of P(A/B).</p>
# <pre>
# <code>
# Formula used for bayes's theorem:
# P(A/b)= (P(B/A)*P(A))/P(B)
# </code>
# </pre>
#
# <p><strong>Example:-</strong></p>
#
# <ul>
#     <li>A rare disease affects 1% of the population ( P(A) = 0.01 ).</li>
#     <li>The medical test for this disease is 99% accurate.</li>
#     <li>We want to find out the probability that a person has the disease given that they test positive.</li>
# </ul>

# %% [markdown]
# <h3 style="color: blue;">Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.</h3>
# <p><b>Answer:</b></p>
# <p>A confidence interval is a range of values, derived from sample data, that is used to estimate the true population parameter with a specified level of confidence.</p>
# <p><b>To calculate the confidence interval, we need some perimeters like value of z score based of confidence level (e.g. 95% = 1.96), sample size n, sample mean, σ is the population standard deviation (or the sample standard deviation, if the population standard deviation is unknown).</b></p>
# <p>Formula used:<br>
# CI = (x bar) plus/minus z*(σ/root of n)
# </p>
# <p><b>Example:</b>If you have sample data where 𝑥 bar (sample mean)=100, 𝜎 (population std.)=15, n (sample size)=50
#  and you want to calculate a 95% confidence interval where z-score for 95% is 1.96:</p>
#  CI= (95.85,104.15), after puting the value in the above formula.

# %% [markdown]
# <h3 style="color: blue;">Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.</h3>
# <p><b>Answer:</b></p>
#
#
# <p>Bayes' Theorem is a fundamental concept in probability theory that allows us to update the probability of a hypothesis (event) given new evidence. The formula is:</p>
#
# <p style="margin-left: 20px;"><strong>P(A|B) = (P(B|A) * P(A)) / P(B)</strong></p>
#
# <p>Where:</p>
# <ul>
#     <li> P(A|B): Posterior probability of event A given evidence B.</li>
#     <li> P(B|A): Probability of evidence B given event A (likelihood).</li>
#     <li> P(A): Prior probability of event A.</li>
#     <li> P(B): Probability of evidence B (normalizing constant).</li>
# </ul>
#
# <p>Example:</p>
#
# <p>A factory produces two types of products: Product A and Product B. Product A has a defect rate of 5%, and Product B has a defect rate of 2%. Given a randomly selected defective product, what is the probability that it is Product A?</p>
#
# <p>We want to find P(A|D), the probability of Product A given the defect.</p>
#
# <p>Let:</p>
# <ul>
#     <li> P(A): Probability of selecting Product A = 0.5 </li>
#     <li> P(B): Probability of selecting Product B = 0.5 </li>
#     <li> P(D|A): Probability of defect given Product A = 0.05 </li>
#     <li> P(D|B): Probability of defect given Product B = 0.02 </li>
# </ul>
#
# <p>First, calculate P(D), the probability of the defect:</p>
#
# <p>P(D) = P(D|A) * P(A) + P(D|B) * P(B)</p>
#
# <p>P(D) = 0.05 * 0.5 + 0.02 * 0.5</p>
#
# <p>P(D) = 0.025 + 0.01</p>
#
# <p>P(D) = 0.035</p>
#
# <p>Now calculate P(A|D), the probability that a randomly selected defective product is Product A:</p>
#
# <p>P(A|D) = (P(D|A) * P(A)) / P(D)</p>
#
# <p>P(A|D) = (0.05 * 0.5) / 0.035</p>
#
# <p>P(A|D) = 0.025 / 0.035</p>
#
# <p>P(A|D) ≈ 0.714 or 71.4%</p>
#
# <p>Therefore, the probability that a randomly selected defective product is Product A is approximately 71.4%. This calculation demonstrates how Bayes' Theorem allows us to update our prior belief (prior probability) about which product is defective given new evidence (likelihood of the defect).</p>

# %% [markdown]
# <h3 style="color: blue;">Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.</h3>
# <p><b>Answer:</b></p>
#     <li> bar{x}: Sample mean = 50 </li>
#     <li> sigma: Standard deviation = 5 </li>
#     <li> Z: Z-score for 95% confidence level is approximately 1.96 </li>
#     <li> n : Sample size (assumed large enough for normal approximation). suppose root of n is 1.  </li>
# </ul>
# <p>
#    CI = 50 ± 1.96 * (5/sqrt(n))
#             <br><br>
#             Since ( n) is not specified, we assume a large enough sample size where (sqrt{n} approx 1):
#             <br><br>
#             CI = 50 ± 1.96 * (5/1)
#             <br><br>
#             CI = 50 ± 1.96 * 5
#             <br><br>
#             CI = 50 ± 9.8
#             <br><br>
#             CI = (40.2, 59.8)
# </p>

# %% [markdown]
# <h3 style="color: blue;">Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error?
# Provide an example of a scenario where a larger sample size would result in a smaller margin of error.</h3>
# <p><b>Answer:</b></p>
#
# <p>The margin of error in a confidence interval (CI) measures the accuracy of an estimate for a population parameter. It represents the maximum amount by which the sample estimate may differ from the true population value.</p>
#
# <p>Mathematically, the margin of error (MOE) for a population mean (μ) is calculated as:</p>
#
# <p style="margin-left: 20px;"><strong>MOE = Z * (σ / √n)</strong></p>
#
# <ul>
#     <li> Z: Z-score corresponding to the desired confidence level (e.g., 1.96 for 95% confidence).</li>
#     <li> σ: Standard deviation of the population (or sample standard deviation).</li>
#     <li> n: Sample size.</li>
# </ul>
#
# <p>Key Points:</p>
# <ul>
#     <li> Larger sample sizes typically result in smaller margins of error because increasing the sample size reduces the standard error of the mean (σ / √n).</li>
#     <li> A smaller margin of error indicates a more precise estimate of the population parameter.</li>
# </ul>
#
# <p>Example Scenario:</p>
#
# <p>Suppose we want to estimate the average height of students in a university. We take two different sample sizes and calculate the 95% confidence intervals:</p>
#
# <table>
#     <tr>
#         <th>Sample Size</th>
#         <th>Sample Mean</th>
#         <th>Standard Error</th>
#         <th>Margin of Error (95% CI)</th>
#     </tr>
#     <tr>
#         <td>Sample Size = 50</td>
#         <td>170 cm</td>
#         <td>(5 / √50 ≈ 0.707)</td>
#         <td>(1.96 * 0.707 ≈ 1.385)</td>
#     </tr>
#     <tr>
#         <td>Sample Size = 200</td>
#         <td>170 cm</td>
#         <td>(5 / √200 ≈ 0.354)</td>
#         <td>(1.96 * 0.354 ≈ 0.694)</td>
#     </tr>
# </table>
#
# <p>In this example, with a larger sample size of 200 compared to 50, the margin of error decreases from approximately 1.385 to 0.694. This reduction in margin of error indicates that the estimate of the average height becomes more precise as the sample size increases.</p>

# %% [markdown]
# <h3 style="color: blue;">Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.</h3>
# <p><b>Answer:</b></p>
# <pre><code>
# Given values: data point = 75 <br>
# Population Mean= 70 <br>
# Standard deviation= 5 <br><br>
# Z = ( X<sub>i</sub> - mu )/ sigma <br>
# Z = (75 - 70)/5
# Z = 1
# </code></pre>
#
# <p>So the value of the z score is 1.</p>

# %% [markdown]
# <h3 style="color: blue;">Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.</h3>
# <p><b>Answer:</b></p>
#
# <p><b>Given values:</b></p><br>
# <ul>
# <li>sample size = 50</li>
# <li>sample mean = 6</li>
# <li>sample std = 2.5</li>
# <li>significant level = 95% ( alpha = 0.05)</li>
# <li>Degree of fredom (df) = n-1 = 50-1 = 49</li>
# </ul>
#
# <ul>
# <li>(H<sub>0</sub>): NUll Hypothesis that the new drug have no change in waight loss, mu<sub>0</sub> = 0</li>
# <li>(H<sub>1</sub>): Alternative Hypothesis that the new drug have significantly effective in weight. mu<sub>0</sub> not = 0</li>
# </ul>
#
# <pre>
# <code>
# t = (x bar - mu)/ (s/ root of n)
# t = (6-0)/(2.5/ root of 50)
# t = 6 / (2.5/7.071) = 42.426/2.5 = 16.9704
# t =  16.9704
#
# Using a t-distribution table, the  critical value for df = 49 with alpha = 0.05 is approx 2.0096
# on comparing
# CI and t
# 16.9704 > 2.0096
#
# 16.9704>2.0096, we reject the null hypothesis.
#
# </code>
# </pre>

# %% [markdown]
# <h3 style="color: blue;">Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95% confidence interval for the true proportion of people who are satisfied with their job.</h3>
# <p><b>Answer:</b></p>
#
# <pre><code>
# sample size = 500
# sample proportion (p) = number of staisfied people / total people = 65% = 0.65
#
# SE for proportion = root of (p(p-1)/n)
# SE = root of (0.65(0.65-1)/500)
# SE = root of 0.000455
#
# MOE = z*SE (where z is the critical value for 95% confidence level which is around 1.96)
# MOE = 1.96 * SE
# MOE = approx 0.0417
#
# confidence interval for 95%
# low limit = p - MOE = 0.65−0.0417=0.6083
# high limit = p + MOE = 0.65+0.0417=0.6917
#
# the 95% confidence interval for the true proportion of people who are satisfied with their job is approximately
# 0.6083 to 0.6917.
# </code></pre>

# %% [markdown]
# <h3 style="color: blue;">Q12. A researcher is testing the effectiveness of two different teaching methods on student performance. Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.</h3>
# <p><b>Answer:</b></p>

# %%
import numpy as np
from scipy import stats 

sample_mean_A = 85
sample_mean_B = 82

sample_std_A = 6
sample_std_B = 5

## since the sample size is not given than we assume that the sample size is equal and large enough to test. suppose sample size = 30
sample_size_A = 30
sample_size_B = 30

## genarating the random data for this king of distribution
np.random.seed(0)

sampleA=np.random.normal(sample_mean_A, sample_std_A, sample_size_A)
sampleB=np.random.normal(sample_mean_B, sample_std_B, sample_size_B)

## performing two sample t test
alpha = 0.01

t_stat, p_value = stats.ttest_ind(sampleA, sampleB)
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")



if p_value<alpha:
    print('we reject the null hypothesis and conclude that there is a significant difference between the two teaching methods.')
else :
    print('we fail to reject the null hypothesis and conclude that there is not enough evidence to show a significant difference between the two teaching methods.')
# Out:
# T-statistic: 4.8461
# P-value: 0.0000
# we reject the null hypothesis and conclude that there is a significant difference between the two teaching methods.

# %% [markdown]
# <h3 style="color: blue;">Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean of 65. Calculate the 90% confidence interval for the true population mean.</h3>
# <p><b>Answer:</b></p>

# %%
import numpy as np
from scipy import stats

population_mean = 60
population_std = 8

sample_size = 50
sample_mean = 65

confidence_level = 90 # 90%
alpha = 0.10

z = 1.645 # for 90% 
## since we a known perimeters for population mean and have a large sample size than we conclude the z test.

SEM = 8/(np.sqrt(50))

MOE = z*SEM

## confidence interval
lower_bound = sample_mean-MOE
upper_bound = sample_mean+MOE

print(f'We are 90% confident that the true population mean μ lies within the interval from approximately {lower_bound:.3f} to {upper_bound:.3f}')
# Out:
# We are 90% confident that the true population mean μ lies within the interval from approximately 63.139 to 66.861

# %% [markdown]
# <h3 style="color: blue;">Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.</h3>
# <p><b>Answer:</b></p>

# %%
## null hypothesis that there is no change or no effect 
## alternative hypothesis that there is significant effect in reaction

import numpy as np
## given

sample_size = 30
sample_mean = 0.25
sample_std = 0.05 

alpha = 0.10 # for 90% confidence level
df = 30-1 # df = n-1

critical_value = 1.699 # by using t-table 

t_value = (sample_mean-0)/ (0.05/np.sqrt(sample_size))

if t_value > critical_value :
    print('we reject the null hypothesis. there is sufficient evidence at the 90 percent confidence level to suggest that caffeine has a significant effect on reaction time.')

else :
    print('Failed to reject null hypothesis.')
# Out:
# we reject the null hypothesis. there is sufficient evidence at the 90 percent confidence level to suggest that caffeine has a significant effect on reaction time.
